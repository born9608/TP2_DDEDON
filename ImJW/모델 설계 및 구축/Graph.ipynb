# %%
import pandas as pd
data = pd.read_csv('시군구별매매전세_noise_보간.csv')
data.head()
# Out:
#    Unnamed: 0              시군구    계약년월      면적당보증금            시      면적당매매금
# 0           0  강원특별자치도 강릉시 견소동  201908  207.164427  강원특별자치도 강릉시  228.137412
# 1           1  강원특별자치도 강릉시 견소동  201909  199.646793  강원특별자치도 강릉시  223.839083
# 2           2  강원특별자치도 강릉시 견소동  201910  222.682534  강원특별자치도 강릉시  248.238090
# 3           3  강원특별자치도 강릉시 견소동  201911  260.329239  강원특별자치도 강릉시  248.297844
# 4           4  강원특별자치도 강릉시 견소동  201912  220.911840  강원특별자치도 강릉시  236.294295

# %%
len(set(data['계약년월']))
# Out:
# 48

# %%
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'

matplotlib.rcParams['axes.unicode_minus'] =False

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Extracting "도" information from the "시" column
data['도'] = data['시'].str.split(" ").str[0]

# %%
data
# Out:
#        Unnamed: 0              시군구    계약년월      면적당보증금            시  \
# 0               0  강원특별자치도 강릉시 견소동  201908  207.164427  강원특별자치도 강릉시
# 1               1  강원특별자치도 강릉시 견소동  201909  199.646793  강원특별자치도 강릉시
# 2               2  강원특별자치도 강릉시 견소동  201910  222.682534  강원특별자치도 강릉시
# 3               3  강원특별자치도 강릉시 견소동  201911  260.329239  강원특별자치도 강릉시
# 4               4  강원특별자치도 강릉시 견소동  201912  220.911840  강원특별자치도 강릉시
# ...           ...              ...     ...         ...          ...
# 96427       96427     충청북도 충주시 호암동  202303  259.748017     충청북도 충주시
# 96428       96428     충청북도 충주시 호암동  202304  190.967701     충청북도 충주시
# 96429       96429     충청북도 충주시 호암동  202305  237.558371     충청북도 충주시
# 96430       96430     충청북도 충주시 호암동  202306  315.277732     충청북도 충주시
# 96431       96431     충청북도 충주시 호암동  202307  327.617336     충청북도 충주시
#
#            면적당매매금        도
# 0      228.137412  강원특별자치도
# 1      223.839083  강원특별자치도
# 2      248.238090  강원특별자치도
# 3      248.297844  강원특별자치도
# ...

# %%
data
# Out:
#        Unnamed: 0              시군구    계약년월      면적당보증금            시  \
# 0               0  강원특별자치도 강릉시 견소동  201908  207.164427  강원특별자치도 강릉시
# 1               1  강원특별자치도 강릉시 견소동  201909  199.646793  강원특별자치도 강릉시
# 2               2  강원특별자치도 강릉시 견소동  201910  222.682534  강원특별자치도 강릉시
# 3               3  강원특별자치도 강릉시 견소동  201911  260.329239  강원특별자치도 강릉시
# 4               4  강원특별자치도 강릉시 견소동  201912  220.911840  강원특별자치도 강릉시
# ...           ...              ...     ...         ...          ...
# 96427       96427     충청북도 충주시 호암동  202303  259.748017     충청북도 충주시
# 96428       96428     충청북도 충주시 호암동  202304  190.967701     충청북도 충주시
# 96429       96429     충청북도 충주시 호암동  202305  237.558371     충청북도 충주시
# 96430       96430     충청북도 충주시 호암동  202306  315.277732     충청북도 충주시
# 96431       96431     충청북도 충주시 호암동  202307  327.617336     충청북도 충주시
#
#            면적당매매금        도
# 0      228.137412  강원특별자치도
# 1      223.839083  강원특별자치도
# 2      248.238090  강원특별자치도
# 3      248.297844  강원특별자치도
# ...

# %%
grouped  = data.groupby(['시', '계약년월'])['면적당보증금','면적당매매금'].mean().reset_index()
# Out:
# C:\Users\Jinwooserver\AppData\Local\Temp\ipykernel_14464\4027798934.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped  = data.groupby(['시', '계약년월'])['면적당보증금','면적당매매금'].mean().reset_index()

# %%
grouped
# Out:
#                  시    계약년월      면적당보증금      면적당매매금
# 0      강원특별자치도 강릉시  201908  167.326059  191.381519
# 1      강원특별자치도 강릉시  201909  171.362183  199.219340
# 2      강원특별자치도 강릉시  201910  178.184833  206.526828
# 3      강원특별자치도 강릉시  201911  179.870193  205.994709
# 4      강원특별자치도 강릉시  201912  185.667995  199.125389
# ...            ...     ...         ...         ...
# 11371     충청북도 충주시  202303  205.181950  231.540699
# 11372     충청북도 충주시  202304  195.705127  223.692612
# 11373     충청북도 충주시  202305  198.488458  224.375149
# 11374     충청북도 충주시  202306  212.652833  228.584271
# 11375     충청북도 충주시  202307  201.513091  244.693147
#
# [11376 rows x 4 columns]

# %%
grouped['계약년월'] = pd.to_datetime(grouped['계약년월'], format='%Y%m')

# %%
grouped
# Out:
#                  시    계약년월      면적당보증금      면적당매매금
# 0      강원특별자치도 강릉시  201908  167.326059  191.381519
# 1      강원특별자치도 강릉시  201909  171.362183  199.219340
# 2      강원특별자치도 강릉시  201910  178.184833  206.526828
# 3      강원특별자치도 강릉시  201911  179.870193  205.994709
# 4      강원특별자치도 강릉시  201912  185.667995  199.125389
# ...            ...     ...         ...         ...
# 11371     충청북도 충주시  202303  205.181950  231.540699
# 11372     충청북도 충주시  202304  195.705127  223.692612
# 11373     충청북도 충주시  202305  198.488458  224.375149
# 11374     충청북도 충주시  202306  212.652833  228.584271
# 11375     충청북도 충주시  202307  201.513091  244.693147
#
# [11376 rows x 4 columns]

# %%
# Group by '시' and '계약년월', then calculate the mean of '면적당보증금' and '면적당매매금'
grouped_by_city = df.groupby(['시군구', '계약년월'])['면적당보증금', '면적당매매금'].mean().reset_index()
# Out:
# C:\Users\Jinwooserver\AppData\Local\Temp\ipykernel_14464\1551570894.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_by_city = df.groupby(['시군구', '계약년월'])['면적당보증금', '면적당매매금'].mean().reset_index()

# %%
# Group by '시' and '계약년월', then calculate the mean of '면적당보증금' and '면적당매매금'
grouped_by_city
# Out:
#                    시군구    계약년월      면적당보증금      면적당매매금
# 0      강원특별자치도 강릉시 견소동  201908  207.164427  228.137412
# 1      강원특별자치도 강릉시 견소동  201909  199.646793  223.839083
# 2      강원특별자치도 강릉시 견소동  201910  222.682534  248.238090
# 3      강원특별자치도 강릉시 견소동  201911  260.329239  248.297844
# 4      강원특별자치도 강릉시 견소동  201912  220.911840  236.294295
# ...                ...     ...         ...         ...
# 96427     충청북도 충주시 호암동  202303  259.748017  260.279084
# 96428     충청북도 충주시 호암동  202304  190.967701  271.155606
# 96429     충청북도 충주시 호암동  202305  237.558371  277.110797
# 96430     충청북도 충주시 호암동  202306  315.277732  261.226532
# 96431     충청북도 충주시 호암동  202307  327.617336  350.160886
#
# [96432 rows x 4 columns]

# %%
# Group by '시군구' and '계약년월', then calculate the mean of '면적당보증금' and '면적당매매금'
grouped_by_sigungu = df.groupby(['시군구', '계약년월'])['면적당보증금', '면적당매매금'].mean().reset_index()

# Filter '시군구' that contain "서울"
selected_sigungu_seoul = [sigungu for sigungu in df['시군구'].unique() if "충주시" in sigungu]

# Create a DataFrame with all possible combinations of '시군구' and '계약년월'
all_combinations_sigungu = pd.DataFrame([(sigungu, date) for sigungu in selected_sigungu_seoul for date in all_dates], columns=['시군구', '계약년월'])

# Merge with the grouped_by_sigungu DataFrame to fill missing values with 0
merged_sigungu = pd.merge(all_combinations_sigungu, grouped_by_sigungu, on=['시군구', '계약년월'], how='left').fillna(0)

# Convert '계약년월' to datetime format
merged_sigungu['계약년월'] = pd.to_datetime(merged_sigungu['계약년월'], format='%Y%m')

# Plotting
fig, axes = plt.subplots(nrows=len(selected_sigungu_seoul), figsize=(10, 5 * len(selected_sigungu_seoul)))

for ax, sigungu in zip(axes, selected_sigungu_seoul):
    subset = merged_sigungu[merged_sigungu['시군구'] == sigungu]
    ax.plot(subset['계약년월'], subset['면적당보증금'], color='blue', marker='o', label='면적당보증금')
    ax.plot(subset['계약년월'], subset['면적당매매금'], color='red', marker='o', label='면적당매매금')
    ax.set_title(sigungu)
    ax.set_xlabel('계약년월')
    ax.set_ylabel('금액 평균')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jinwooserver\AppData\Local\Temp\ipykernel_14464\2976985699.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_by_sigungu = df.groupby(['시군구', '계약년월'])['면적당보증금', '면적당매매금'].mean().reset_index()
